# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (2.0.2)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
# Steps

# 0. Preprocess + EDA + Feature Selection
# 1. Extract input and output cols
# 2. Scale the values
# 3. Train test split
# 4. Train the model
# 5. Evaluate the model/model selection

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'])

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#       3 X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 86   5.1  128.0
# 10   6.0   45.0
# 55   7.8  114.0
# 78   6.1   81.0
# ..   ...    ...
# 65   8.1  166.0
# 9    5.1   66.0
# 36   5.7  140.0
# 84   5.7  169.0
# 91   7.5  158.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 0     1
# 86    0
# 10    1
# 55    1
# 78    0
#      ..
# 65    1
# 9     0
# 36    0
# 84    0
# 91    1
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 39   4.6  146.0
# 27   6.0  124.0
# 75   4.8  169.0
# 50   3.5  233.0
# 33   6.0  149.0
# 58   8.0   79.0
# 99   6.2  113.0
# 19   5.2  132.0
# 16   5.2  224.0
# 20   6.6  120.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.68102202,  0.05880948],
#        [-0.82907028,  0.19047249],
#        [-0.02960965, -1.9951335 ],
#        [ 1.5693116 , -0.17818394],
#        [ 0.05921931, -1.04715982],
#        [-0.11843861, -0.38884476],
#        [-0.56258341, -0.17818394],
#        [-0.91789924, -0.78383379],
#        [-1.0067282 ,  0.79612234],
#        [ 2.19111431, -0.02018833],
#        [ 0.68102202,  0.53279632],
#        [-1.18438612, -1.81080528],
#        [ 0.76985098, -0.65217078],
#        [ 1.39165369,  0.19047249],
#        [ 1.30282473,  0.24313769],
#        [-1.80618883, -1.20515543],
#        [ 1.12516681,  0.42746591],
#        [ 0.41453514,  1.03311576],
#        [ 1.12516681, -0.9154968 ],
#        [ 0.68102202, -0.23084915],
#        [ 1.21399577,  0.2958029 ],
#        [ 0.05921931,  0.2958029 ],
#        [-1.45087299,  0.74345714],
#        [ 0.23687722,  0.19047249],
#        [-0.02960965, -1.44214885],
#        [-1.18438612,  0.00614427],
#        [ 2.0134564 ,  1.24377658],
#        [ 0.94750889, -1.91613569],
#        [-2.42799154,  1.63876561],
#        [ 1.30282473, -1.57381186],
#        [-0.65141236, -0.17818394],
#        [-0.20726757,  0.55912892],
#        [ 0.32570618,  0.53279632],
#        [ 0.85867993, -0.23084915],
#        [-0.82907028,  1.4544374 ],
#        [-1.09555716,  1.11211357],
#        [ 1.83579848,  0.74345714],
#        [ 0.76985098,  0.45379851],
#        [ 0.85867993,  0.48013111],
#        [-0.29609653,  0.58546152],
#        [ 0.68102202, -0.8101664 ],
#        [ 0.23687722,  0.16413989],
#        [-0.56258341, -0.36251216],
#        [-0.74024132, -0.28351435],
#        [-0.74024132,  1.05944836],
#        [ 0.32570618, -0.12551874],
#        [-0.20726757,  1.19111137],
#        [-1.0067282 , -1.57381186],
#        [ 1.39165369, -0.836499  ],
#        [ 0.85867993,  1.42810479],
#        [ 0.76985098,  0.48013111],
#        [-0.56258341,  0.37480071],
#        [-1.18438612, -0.8891642 ],
#        [-1.53970195,  2.08641985],
#        [ 0.59219306,  0.87512015],
#        [-0.02960965, -0.49417517],
#        [ 1.12516681, -1.86347049],
#        [ 0.41453514, -0.8101664 ],
#        [ 1.12516681, -0.12551874],
#        [ 0.5033641 ,  0.45379851],
#        [-1.89501779, -0.30984695],
#        [ 0.94750889,  0.79612234],
#        [-1.09555716, -0.23084915],
#        [-1.80618883, -0.54684037],
#        [-1.09555716,  0.53279632],
#        [-0.65141236,  0.00614427],
#        [-0.91789924, -0.07285353],
#        [-1.0067282 , -0.02018833],
#        [-1.0067282 ,  0.90145275],
#        [ 0.41453514, -2.20579431],
#        [-0.74024132, -0.8101664 ],
#        [ 0.05921931, -1.46848145],
#        [-0.29609653,  0.2958029 ],
#        [ 0.85867993,  2.06008725],
#        [ 0.85867993, -1.49481405],
#        [ 0.41453514,  0.24313769],
#        [ 0.05921931,  0.92778535],
#        [-0.56258341,  0.48013111],
#        [ 0.59219306,  1.61243301],
#        [ 0.05921931, -0.46784257],
#        [-1.0067282 ,  1.98108944],
#        [-1.45087299, -2.0741313 ],
#        [ 0.23687722, -0.46784257],
#        [-0.91789924, -1.52114666],
#        [-1.0067282 ,  0.3484681 ],
#        [ 1.83579848,  1.19111137],
#        [-0.82907028, -1.44214885],
#        [-0.29609653,  0.50646372],
#        [-0.29609653,  1.27010918],
#        [ 1.30282473,  0.98045056]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-1.27321507,  0.66445933],
#        [-0.02960965,  0.08514208],
#        [-1.09555716,  1.27010918],
#        [-2.25033362,  2.95539572],
#        [-0.02960965,  0.74345714],
#        [ 1.74696952, -1.09982502],
#        [ 0.14804826, -0.20451654],
#        [-0.74024132,  0.2958029 ],
#        [-0.74024132,  2.7184023 ],
#        [ 0.5033641 , -0.02018833]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
# model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 39    0
# 27    1
# 75    0
# 50    0
# 33    0
# 58    1
# 99    1
# 19    0
# 16    0
# 20    1
# Name: placement, dtype: int64

# %%
y_pred
# Out:
# array([0, 1, 0, 0, 1, 1, 1, 0, 0, 1])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 90.0

# %%
from mlxtend.plotting import plot_decision_regions
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 from mlxtend.plotting import plot_decision_regions
#
# ModuleNotFoundError: No module named 'mlxtend'

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.3-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (1.14.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (2.0.2)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (1.6.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (3.9.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\cmeht\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.3-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 180.4 kB/s eta 0:00:05
#    --------------- ------------------------ 0.5/1.4 MB 180.4 kB/s eta 0:00:05
#    ----------------------- ---------------- 0.8/1.4 MB 277.3 kB/s eta 0:00:03
#    ----------------------- ---------------- 0.8/1.4 MB 277.3 kB/s eta 0:00:03
#    ------------------------------- -------- 1.0/1.4 MB 344.6 kB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.4 MB 344.6 kB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 391.9 kB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.3

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
#
# NameError: name 'plot_decision_regions' is not defined

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >
